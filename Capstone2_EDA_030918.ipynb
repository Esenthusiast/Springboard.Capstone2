# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import locale
from locale import atof

# %%
df_World_Bank =pd.read_csv('C:/Users/Esme/Desktop/Springboard/Capstone_2/World_bank_USA/API_USA_DS2_en_csv_v2.csv', index_col = 0, header= 2, sep=",", engine = 'python', na_filter = False, thousands=',')

# %%
df_2016_unedited =pd.read_csv('C:/Users/Esme/Desktop/Springboard/Capstone_2/oesm16nat/oesm16nat/national_M2016_dl.csv', index_col = 0, header= 0, sep=",", engine = 'python', na_filter = False, thousands=',')
df_2015_unedited =pd.read_csv('C:/Users/Esme/Desktop/Springboard/Capstone_2/oesm15nat/oesm15nat/national_M2015_dl.csv', index_col = 0, header= 0, sep=",", engine = 'python', na_filter = False, thousands=',')
df_2014_unedited =pd.read_csv('C:/Users/Esme/Desktop/Springboard/Capstone_2/oesm14nat/oesm14nat/national_M2014_dl.csv', index_col = 0, header= 0, sep=",", engine = 'python', na_filter = False, thousands=',')
df_2013_unedited =pd.read_csv('C:/Users/Esme/Desktop/Springboard/Capstone_2/oesm13nat/oesm13nat/national_M2013_dl.csv', index_col = 0, header= 0, sep=",", engine = 'python', na_filter = False, thousands=',')
df_2012_unedited =pd.read_csv('C:/Users/Esme/Desktop/Springboard/Capstone_2/oesm12nat/oesm12nat/national_M2012_dl.csv', index_col = 0, header= 0, sep=",", engine = 'python', na_filter = False, thousands=',')
df_2011_unedited =pd.read_csv('C:/Users/Esme/Desktop/Springboard/Capstone_2/oesm11nat/national_M2011_dl.csv', index_col = 0, header= 0, sep=",", engine = 'python', na_filter = False, thousands=',')
df_2010_unedited =pd.read_csv('C:/Users/Esme/Desktop/Springboard/Capstone_2/oesm10nat/national_M2010_dl.csv', index_col = 0, header= 0, sep=",", engine = 'python', na_filter = False, thousands=',')
df_2009_unedited =pd.read_csv('C:/Users/Esme/Desktop/Springboard/Capstone_2/oesm09nat/national_dl.csv', index_col = 0, header= 0, sep=",", engine = 'python', na_filter = False, thousands=',')

df_2008_unedited =pd.read_csv('C:/Users/Esme/Desktop/Springboard/Capstone_2/oesm08nat/national__M2008_dl.csv', index_col = 0, header= 0, sep=",", engine = 'python', na_filter = False, thousands=',')
df_2007_unedited =pd.read_csv('C:/Users/Esme/Desktop/Springboard/Capstone_2/oesm07nat/national_May2007_dl.csv', index_col = 0, header= 0, sep=",", engine = 'python', na_filter = False, thousands=',')
df_2006_unedited =pd.read_csv('C:/Users/Esme/Desktop/Springboard/Capstone_2/oesm06nat/national_may2006_dl.csv', index_col = 0, header= 0, sep=",", engine = 'python', na_filter = False, thousands=',')
df_2005_unedited =pd.read_csv('C:/Users/Esme/Desktop/Springboard/Capstone_2/oesm05nat/national_may2005_dl.csv', index_col = 0, header= 0, sep=",", engine = 'python', na_filter = False, thousands=',')
df_2004_unedited =pd.read_csv('C:/Users/Esme/Desktop/Springboard/Capstone_2/oesm04nat/national_may2004_dl.csv', index_col = 0, header= 0, sep=",", engine = 'python', na_filter = False, thousands=',')
df_2003_unedited =pd.read_csv('C:/Users/Esme/Desktop/Springboard/Capstone_2/oesm03nat/national_may2003_dl.csv', index_col = 0, header= 0, sep=",", engine = 'python', na_filter = False, thousands=',')
df_2002_unedited =pd.read_csv('C:/Users/Esme/Desktop/Springboard/Capstone_2/oes02nat/national_2002_dl.csv', index_col = 0, header= 0, sep=",", engine = 'python', na_filter = False, thousands=',')

# %%
df_2002_unedited
# Out:
#                                                       occ_titl  group  \
# ï»¿occ_code
# 00-0000                                        All Occupations  major
# 11-0000                                 Management Occupations  major
# 11-1011                                       Chief Executives
# 11-1021                        General and Operations Managers
# 11-1031                                            Legislators
# 11-2011                    Advertising and Promotions Managers
# 11-2021                                     Marketing Managers
# 11-2022                                         Sales Managers
# 11-2031                              Public Relations Managers
# 11-3011                       Administrative Services Managers
# 11-3021              Computer and Information Systems Managers
# 11-3031                                     Financial Managers
# 11-3040                               Human Resources Managers
# 11-3051                         Industrial Production Managers
# 11-3061                                    Purchasing Managers
# 11-3071      Transportation, Storage, and Distribution Mana...
# 11-9011           Farm, Ranch, and Other Agricultural Managers
# 11-9021                                  Construction Managers
# 11-9031      Education Administrators, Preschool and Child ...
# 11-9032      Education Administrators, Elementary and Secon...
# 11-9033                Education Administrators, Postsecondary
# 11-9041                                   Engineering Managers
# 11-9051                                  Food Service Managers
# 11-9061                                      Funeral Directors
# 11-9071                                        Gaming Managers
# 11-9081                                       Lodging Managers
# 11-9111                   Medical and Health Services Managers
# 11-9121                              Natural Sciences Managers
# 11-9131                   Postmasters and Mail Superintendents
# 11-9141      Property, Real Estate, and Community Associati...
# ...                                                        ...    ...
# 53-4013      Rail Yard Engineers, Dinkey Operators, and Hos...
# 53-4021           Railroad Brake, Signal, and Switch Operators
# 53-4031                    Railroad Conductors and Yardmasters
# 53-4041                         Subway and Streetcar Operators
# 53-5011                              Sailors and Marine Oilers
# 53-5021           Captains, Mates, and Pilots of Water Vessels
# 53-5022                                    Motorboat Operators
# 53-5031                                         Ship Engineers
# 53-6011                                Bridge and Lock Tenders
# 53-6021                                 Parking Lot Attendants
# 53-6031                             Service Station Attendants
# 53-6041                                    Traffic Technicians
# 53-6051                              Transportation Inspectors
# 53-7011                         Conveyor Operators and Tenders
# 53-7021                              Crane and Tower Operators
# 53-7031                                       Dredge Operators
# 53-7032      Excavating and Loading Machine and Dragline Op...
# 53-7033          Loading Machine Operators, Underground Mining
# 53-7041                              Hoist and Winch Operators
# 53-7051                 Industrial Truck and Tractor Operators
# 53-7061                     Cleaners of Vehicles and Equipment
# 53-7062      Laborers and Freight, Stock, and Material Move...
# 53-7063                         Machine Feeders and Offbearers
# 53-7064                            Packers and Packagers, Hand
# 53-7071       Gas Compressor and Gas Pumping Station Operators
# 53-7072                Pump Operators, Except Wellhead Pumpers
# 53-7073                                       Wellhead Pumpers
# 53-7081              Refuse and Recyclable Material Collectors
# 53-7111                                  Shuttle Car Operators
# 53-7121                      Tank Car, Truck, and Ship Loaders
#
#                tot_emp  emp_prse h_mean  a_mean mean_prse h_wpct10 h_wpct25  \
# ï»¿occ_code
# 00-0000      127523760       0.1   17.1   35560       0.2     6.95     8.93
# 11-0000        7092460       0.3  37.92   78870       0.2    15.31    21.86
# 11-1011         452400       0.7  64.89  134960       0.3    24.83    38.88
# 11-1021        1998350       0.4  40.19   83590       0.2    15.72    21.98
# 11-1031          64650       3.5  14.62   30420       2.2     5.83     6.34
# 11-2011          81090       1.2  33.27   69200       0.7    14.57    19.01
# 11-2021         192080       1.0  41.91   87170       0.4     19.1    26.33
# 11-2022         328060       0.7   41.4   86110       0.3    17.95    24.72
# 11-2031          62640       1.9  33.59   69870       0.8    15.84    21.35
# 11-3011         306370       0.8  28.54   59350       0.4    12.56     17.4
# 11-3021         264790       0.8  43.48   90440       0.3    22.81    30.84
# 11-3031         563020       0.9  39.94   83080       0.5    18.81    25.23
# 11-3040         193360       0.8  34.12   70960       0.3    17.44     22.8
# 11-3051         173960       0.6  35.09   72980       0.3    18.74    24.38
# 11-3061         105010       0.8  31.85   66250       0.4    15.54       21
# 11-3071         107400       1.0  31.29   65070       0.4     16.5    21.78
# 11-9011           5630       4.1  23.65   49200       1.3    11.74    15.68
# 11-9021         208360       1.4  34.24   71210       0.7    18.33    23.42
# 11-9031          52700       2.0  18.84   39190       1.4     9.58    12.12
# 11-9032         204340       0.9      *   74050         2        *        *
# 11-9033          96910       1.6  34.44   71630       0.8    17.26    22.62
# 11-9041         205390       1.0  46.03   95750       0.3    27.81    34.85
# 11-9051         249710       4.4  19.75   41090       5.7    10.46    13.42
# 11-9061          21740       2.7  24.83   51650       2.5       12    16.13
# 11-9071           3760       5.3  29.29   60910       1.4     14.9    19.91
# 11-9081          31170       2.6  18.32   38110       0.9     9.81    12.55
# 11-9111         228290       0.7  33.35   69370       0.4    18.01    23.03
# 11-9121          42470       2.2  43.46   90400       1.3    21.94    28.85
# 11-9131          26470       0.0  23.36   48590       0.1    16.88    19.46
# 11-9141         156290       2.2   22.3   46390       0.9     8.39    12.24
# ...                ...       ...    ...     ...       ...      ...      ...
# 53-4013           4600       6.5  19.52   40600       2.1    12.54    15.17
# 53-4021          15030       5.7  21.99   45750       1.3    13.32    17.13
# 53-4031          38070       5.3  23.69   49280       2.6    15.19     18.1
# 53-4041           7250       6.6  22.51   46810         4    17.87    20.48
# 53-5011          25360       3.8  14.69   30550       1.3     7.92    10.29
# 53-5021          22530       3.5  24.73   51430       1.3    12.28    17.48
# 53-5022           3600      18.7  14.71   30590       6.3     7.51     8.77
# 53-5031           8020       6.6  25.09   52190       1.7    12.95    18.31
# 53-6011           3900       7.5  15.17   31560       2.2      7.6     9.87
# 53-6021         108460       2.2    8.3   17270       0.6      6.1     6.89
# 53-6031         102550       2.1   8.54   17770       0.7     6.19     6.98
# 53-6041           5370       2.0   16.5   34320       1.7     9.52     11.6
# 53-6051          28340       2.5  23.06   47970       1.3    10.54    16.68
# 53-7011          59240       2.4   12.4   25790       0.8     8.04      9.6
# 53-7021          49060       2.6  18.42   38320       1.2    11.07     13.5
# 53-7031           2850      10.6   14.3   29740       2.9     8.17    10.25
# 53-7032          67210       3.6  16.77   34880       1.8    10.01    12.26
# 53-7033           3200       8.5  15.62   32480       1.9    10.25     12.4
# 53-7041           8970       5.8  17.29   35960       2.3     9.45    11.47
# 53-7051         586660       0.8  13.34   27740       0.4     8.82    10.28
# 53-7061         311070       1.0   9.05   18830       0.4     6.12     6.94
# 53-7062        2217590       1.1  10.32   21460       0.3     6.64     7.69
# 53-7063         162670       1.6  11.23   23360       0.5     7.28     8.53
# 53-7064         927740       1.1   8.73   18160       0.3     6.12     6.89
# 53-7071           6920      10.8  20.64   42920       2.8    12.77    16.12
# 53-7072          12360      10.6  18.58   38640       2.6     9.47    12.66
# 53-7073          10280      12.5  16.48   34290       2.3     9.33    12.18
# 53-7081         132290       4.1  12.55   26090       2.1     6.28     8.18
# 53-7111           3070       6.3  17.81   37050       1.2    13.09    15.17
# 53-7121          16960       5.3  17.03   35420       2.1     9.52    11.83
#
#             h_median h_wpct75 h_wpct90 a_wpct10 a_wpct25 a_median a_wpct75  \
# ï»¿occ_code
# 00-0000        13.31    20.84     31.2    14450    18580    27690    43340
# 11-0000        32.27    46.79    69.53    31850    45470    67120    97320
# 11-1011         60.7        #        #    51650    80860   126260        #
# 11-1021         32.8    50.47        #    32700    45720    68210   104970
# 11-1031         7.32    18.53    33.36    12130    13180    15220    38540
# 11-2011        27.47    41.21    60.13    30310    39550    57130    85710
# 11-2021        37.62    52.49        #    39730    54760    78250   109190
# 11-2022        36.08    51.82        #    37340    51430    75040   107790
# 11-2031        29.15    41.15    56.63    32960    44410    60640    85590
# 11-3011        25.24    35.86    48.02    26120    36190    52500    74590
# 11-3021        40.98    52.86    67.52    47440    64150    85240   109950
# 11-3031        35.26    48.39    68.39    39120    52490    73340   100660
# 11-3040        31.11    42.36    54.95    36280    47420    64710    88100
# 11-3051        32.37    42.73    55.17    38980    50710    67320    88880
# 11-3061        28.79     39.4    51.99    32330    43670    59890    81950
# 11-3071        28.68     37.8    48.51    34330    45290    59660    78620
# 11-9011        21.03    28.52    38.99    24410    32620    43740    59330
# 11-9021        30.53    40.43    54.23    38130    48720    63500    84080
# 11-9031        16.03    22.48    32.53    19930    25200    33340    46760
# 11-9032            *        *        *    48700    58820    71490    87540
# 11-9033        31.08    42.36    55.87    35910    47050    64640    88110
# 11-9041        43.71    54.83    67.97    57840    72480    90930   114050
# 11-9051        17.21    22.65    32.45    21760    27910    35790    47120
# 11-9061        20.85    27.95    40.42    24950    33540    43380    58140
# 11-9071        26.12    34.92    47.39    30980    41410    54330    72630
# 11-9081        16.33    21.48    28.57    20400    26110    33970    44670
# 11-9111         29.5    38.53    52.44    37460    47910    61370    80150
# 11-9121        39.54     53.4    69.51    45640    60000    82250   111070
# 11-9131        23.34    26.95    31.95    35110    40470    48540    56050
# 11-9141        17.73    26.92    41.66    17450    25470    36880    56000
# ...              ...      ...      ...      ...      ...      ...      ...
# 53-4013        18.07       21    25.12    26090    31550    37590    43680
# 53-4021        20.93    26.32    33.12    27710    35620    43520    54750
# 53-4031        21.39    28.61    37.88    31600    37650    44490    59510
# 53-4041        23.54     25.8    27.16    37160    42600    48970    53670
# 53-5011        13.64    18.74    22.16    16470    21400    28370    38990
# 53-5021        23.97     30.2    37.04    25540    36360    49850    62810
# 53-5022        12.71    19.83    24.84    15620    18240    26440    41250
# 53-5031        24.61    31.51    37.37    26930    38080    51190    65540
# 53-6011        16.98    19.52    21.17    15800    20530    35310    40610
# 53-6021         7.84     9.12    11.17    12690    14320    16320    18970
# 53-6031         7.97     9.36    11.68    12880    14520    16570    19470
# 53-6041        15.22    20.61    26.06    19810    24140    31650    42860
# 53-6051         23.3    27.91    36.12    21930    34690    48450    58050
# 53-7011        11.66    14.23    18.39    16730    19970    24250    29590
# 53-7021        17.47    22.07    28.02    23030    28080    36330    45910
# 53-7031        13.33     17.1    22.71    16990    21310    27730    35570
# 53-7032        15.58    20.56    26.15    20820    25500    32410    42760
# 53-7033        15.35    18.47    21.72    21320    25790    31930    38420
# 53-7041        15.09    21.02    30.85    19650    23850    31400    43730
# 53-7051        12.54    15.59    19.52    18360    21380    26070    32430
# 53-7061          8.2    10.31    13.32    12740    14430    17060    21450
# 53-7062         9.48    11.94    15.49    13820    15990    19710    24830
# 53-7063         10.5    13.19    16.63    15130    17740    21840    27440
# 53-7064         8.03    10.03    12.65    12720    14340    16700    20860
# 53-7071        20.44    25.01    28.73    26550    33530    42510    52030
# 53-7072        17.53    24.99    28.17    19700    26330    36470    51980
# 53-7073        16.24    20.94    23.74    19420    25330    33770    43560
# 53-7081         11.6    15.92    21.07    13070    17010    24130    33120
# 53-7111        18.44    20.71    22.17    27230    31550    38360    43070
# 53-7121        15.63    21.81    27.38    19810    24600    32500    45360
#
#             a_wpct90 annual
# ï»¿occ_code
# 00-0000        64900
# 11-0000       144620
# 11-1011            #
# 11-1021            #
# 11-1031        69380
# 11-2011       125070
# 11-2021            #
# 11-2022            #
# 11-2031       117780
# 11-3011        99870
# 11-3021       140440
# 11-3031       142260
# 11-3040       114300
# 11-3051       114750
# 11-3061       108140
# 11-3071       100900
# 11-9011        81100
# 11-9021       112810
# 11-9031        67650
# 11-9032       104870   TRUE
# 11-9033       116210
# 11-9041       141380
# 11-9051        67490
# 11-9061        84060
# 11-9071        98570
# 11-9081        59420
# 11-9111       109080
# 11-9121       144590
# 11-9131        66450
# 11-9141        86650
# ...              ...    ...
# 53-4013        52260
# 53-4021        68900
# 53-4031        78790
# 53-4041        56500
# 53-5011        46090
# 53-5021        77050
# 53-5022        51670
# 53-5031        77740
# 53-6011        44030
# 53-6021        23230
# 53-6031        24300
# 53-6041        54200
# 53-6051        75120
# 53-7011        38250
# 53-7021        58280
# 53-7031        47240
# 53-7032        54390
# 53-7033        45180
# 53-7041        64160
# 53-7051        40590
# 53-7061        27710
# 53-7062        32220
# 53-7063        34600
# 53-7064        26310
# 53-7071        59750
# 53-7072        58590
# 53-7073        49370
# 53-7081        43820
# 53-7111        46120
# 53-7121        56940
#
# [734 rows x 18 columns]

# %%
# function to clean up, set read-able column titles, and add year, so I can concatenate into one DF w/out loosing data


def clean_labor_df(df, year):
    df= df.reset_index()
    df.columns= ['OCC_Code','Occupation_title','OCC_group', 'total_employment', 'Employment_RSE', 'mean_hourly_wage','mean_annual_wage', 'mean_wage_RSE', 'hourly_10th_percentile_wage', 'hourly_25th_percentile_wage', 'hourly_median_wage', 'hourly 75_percentile_wage', 'hourly_90th_percentile_wage', 'annual_10th_percentile_wage', 'annual_25th_percentile_wage', 'annual_median_percentile_wage', 'annual_75th_percentile_wage', 'annual_90th_percentile_wage', 'Annual:T/F', 'Wage:T/F' ]
    df['Year']= year
    df1= df.drop(['Annual:T/F', 'Wage:T/F'], axis=1)
    df2=df1.replace('**', np.nan)
    df3= df2.replace('#', np.nan)
    df3['total_employment']=pd.to_numeric(df3['total_employment'], errors='coerce', downcast='float')
    df3['mean_hourly_wage']= pd.to_numeric(df3['mean_hourly_wage'], errors='coerce', downcast='float')
    df3['mean_annual_wage']= pd.to_numeric(df3['mean_annual_wage'], errors='coerce', downcast='float')
    df3['hourly_median_wage']= pd.to_numeric(df3['hourly_median_wage'], errors='coerce', downcast='float')
    
    
    return df3

# %%
# second function for  the multivalue index in 2006 data
def clean_labor_df2(df, year):
    df.columns= df.columns.get_level_values(0)
    df= df.reset_index()
    df.columns= ['OCC_Code','Occupation_title','OCC_group', 'total_employment', 'Employment_RSE', 'mean_hourly_wage','mean_annual_wage', 'mean_wage_RSE', 'hourly_10th_percentile_wage', 'hourly_25th_percentile_wage', 'hourly_median_wage', 'hourly 75_percentile_wage', 'hourly_90th_percentile_wage', 'annual_10th_percentile_wage', 'annual_25th_percentile_wage', 'annual_median_percentile_wage', 'annual_75th_percentile_wage', 'annual_90th_percentile_wage', 'Annual:T/F', 'Wage:T/F' ]
    df['Year']= year
    df1= df.drop(['Annual:T/F', 'Wage:T/F'], axis=1)
    df2=df1.replace('**', np.nan)
    df3= df2.replace('#', np.nan)
    df3['total_employment']=pd.to_numeric(df3['total_employment'], errors='coerce', downcast='float')
    df3['mean_hourly_wage']= pd.to_numeric(df3['mean_hourly_wage'], errors='coerce', downcast='float')
    df3['mean_annual_wage']= pd.to_numeric(df3['mean_annual_wage'], errors='coerce', downcast='float')
    df3['hourly_median_wage']= pd.to_numeric(df3['hourly_median_wage'], errors='coerce', downcast='float')
    
    

    return df3

# %%
# second function for  the multivalue index and missing data in 2003 and 2002
def clean_labor_df3(df, year):

    df= df.reset_index()
    df.columns= ['OCC_Code','Occupation_title','OCC_group', 'total_employment', 'Employment_RSE', 'mean_hourly_wage','mean_annual_wage', 'mean_wage_RSE', 'hourly_10th_percentile_wage', 'hourly_25th_percentile_wage', 'hourly_median_wage', 'hourly 75_percentile_wage', 'hourly_90th_percentile_wage', 'annual_10th_percentile_wage', 'annual_25th_percentile_wage', 'annual_median_percentile_wage', 'annual_75th_percentile_wage', 'annual_90th_percentile_wage', 'Annual:T/F']
    df['Year']= year
    df1= df.drop(['Annual:T/F'], axis=1)
    df2=df1.replace('**', np.nan)
    df3= df2.replace('#', np.nan)
    df3['total_employment']=pd.to_numeric(df3['total_employment'], errors='coerce', downcast='float')
    df3['mean_hourly_wage']= pd.to_numeric(df3['mean_hourly_wage'], errors='coerce', downcast='float')
    df3['mean_annual_wage']= pd.to_numeric(df3['mean_annual_wage'], errors='coerce', downcast='float')
    df3['hourly_median_wage']= pd.to_numeric(df3['hourly_median_wage'], errors='coerce', downcast='float')
    

    return df3

# %%
df_2016= clean_labor_df(df_2016_unedited, '2016')
df_2015= clean_labor_df(df_2015_unedited, '2015')
df_2014= clean_labor_df(df_2014_unedited, '2014')
df_2013= clean_labor_df(df_2013_unedited, '2013')
df_2012= clean_labor_df(df_2012_unedited, '2012')
df_2011= clean_labor_df(df_2011_unedited, '2011')
df_2010= clean_labor_df(df_2010_unedited, '2010')
df_2009= clean_labor_df(df_2009_unedited, '2009')
df_2008= clean_labor_df(df_2008_unedited, '2008')
df_2007= clean_labor_df(df_2007_unedited, '2007')
df_2006= clean_labor_df2(df_2006_unedited, '2006')
df_2005= clean_labor_df(df_2005_unedited, '2005')
df_2004= clean_labor_df(df_2004_unedited, '2004')
df_2003= clean_labor_df3(df_2003_unedited, '2003')
df_2002= clean_labor_df3(df_2002_unedited, '2002')

# %%
df_2002
# Out:
#     OCC_Code                                   Occupation_title OCC_group  \
# 0    00-0000                                    All Occupations     major
# 1    11-0000                             Management Occupations     major
# 2    11-1011                                   Chief Executives
# 3    11-1021                    General and Operations Managers
# 4    11-1031                                        Legislators
# 5    11-2011                Advertising and Promotions Managers
# 6    11-2021                                 Marketing Managers
# 7    11-2022                                     Sales Managers
# 8    11-2031                          Public Relations Managers
# 9    11-3011                   Administrative Services Managers
# 10   11-3021          Computer and Information Systems Managers
# 11   11-3031                                 Financial Managers
# 12   11-3040                           Human Resources Managers
# 13   11-3051                     Industrial Production Managers
# 14   11-3061                                Purchasing Managers
# 15   11-3071  Transportation, Storage, and Distribution Mana...
# 16   11-9011       Farm, Ranch, and Other Agricultural Managers
# 17   11-9021                              Construction Managers
# 18   11-9031  Education Administrators, Preschool and Child ...
# 19   11-9032  Education Administrators, Elementary and Secon...
# 20   11-9033            Education Administrators, Postsecondary
# 21   11-9041                               Engineering Managers
# 22   11-9051                              Food Service Managers
# 23   11-9061                                  Funeral Directors
# 24   11-9071                                    Gaming Managers
# 25   11-9081                                   Lodging Managers
# 26   11-9111               Medical and Health Services Managers
# 27   11-9121                          Natural Sciences Managers
# 28   11-9131               Postmasters and Mail Superintendents
# 29   11-9141  Property, Real Estate, and Community Associati...
# ..       ...                                                ...       ...
# 704  53-4013  Rail Yard Engineers, Dinkey Operators, and Hos...
# 705  53-4021       Railroad Brake, Signal, and Switch Operators
# 706  53-4031                Railroad Conductors and Yardmasters
# 707  53-4041                     Subway and Streetcar Operators
# 708  53-5011                          Sailors and Marine Oilers
# 709  53-5021       Captains, Mates, and Pilots of Water Vessels
# 710  53-5022                                Motorboat Operators
# 711  53-5031                                     Ship Engineers
# 712  53-6011                            Bridge and Lock Tenders
# 713  53-6021                             Parking Lot Attendants
# 714  53-6031                         Service Station Attendants
# 715  53-6041                                Traffic Technicians
# 716  53-6051                          Transportation Inspectors
# 717  53-7011                     Conveyor Operators and Tenders
# 718  53-7021                          Crane and Tower Operators
# 719  53-7031                                   Dredge Operators
# 720  53-7032  Excavating and Loading Machine and Dragline Op...
# 721  53-7033      Loading Machine Operators, Underground Mining
# 722  53-7041                          Hoist and Winch Operators
# 723  53-7051             Industrial Truck and Tractor Operators
# 724  53-7061                 Cleaners of Vehicles and Equipment
# 725  53-7062  Laborers and Freight, Stock, and Material Move...
# 726  53-7063                     Machine Feeders and Offbearers
# 727  53-7064                        Packers and Packagers, Hand
# 728  53-7071   Gas Compressor and Gas Pumping Station Operators
# 729  53-7072            Pump Operators, Except Wellhead Pumpers
# 730  53-7073                                   Wellhead Pumpers
# 731  53-7081          Refuse and Recyclable Material Collectors
# 732  53-7111                              Shuttle Car Operators
# 733  53-7121                  Tank Car, Truck, and Ship Loaders
#
#      total_employment  Employment_RSE  mean_hourly_wage  mean_annual_wage  \
# 0         127523760.0             0.1         17.100000           35560.0
# 1           7092460.0             0.3         37.919998           78870.0
# 2            452400.0             0.7         64.889999          134960.0
# 3           1998350.0             0.4         40.189999           83590.0
# 4             64650.0             3.5         14.620000           30420.0
# 5             81090.0             1.2         33.270000           69200.0
# 6            192080.0             1.0         41.910000           87170.0
# 7            328060.0             0.7         41.400002           86110.0
# 8             62640.0             1.9         33.590000           69870.0
# 9            306370.0             0.8         28.540001           59350.0
# 10           264790.0             0.8         43.480000           90440.0
# 11           563020.0             0.9         39.939999           83080.0
# 12           193360.0             0.8         34.119999           70960.0
# 13           173960.0             0.6         35.090000           72980.0
# 14           105010.0             0.8         31.850000           66250.0
# 15           107400.0             1.0         31.290001           65070.0
# 16             5630.0             4.1         23.650000           49200.0
# 17           208360.0             1.4         34.240002           71210.0
# 18            52700.0             2.0         18.840000           39190.0
# 19           204340.0             0.9               NaN           74050.0
# 20            96910.0             1.6         34.439999           71630.0
# 21           205390.0             1.0         46.029999           95750.0
# 22           249710.0             4.4         19.750000           41090.0
# 23            21740.0             2.7         24.830000           51650.0
# 24             3760.0             5.3         29.290001           60910.0
# 25            31170.0             2.6         18.320000           38110.0
# 26           228290.0             0.7         33.349998           69370.0
# 27            42470.0             2.2         43.459999           90400.0
# 28            26470.0             0.0         23.360001           48590.0
# 29           156290.0             2.2         22.299999           46390.0
# ..                ...             ...               ...               ...
# 704            4600.0             6.5         19.520000           40600.0
# 705           15030.0             5.7         21.990000           45750.0
# 706           38070.0             5.3         23.690001           49280.0
# 707            7250.0             6.6         22.510000           46810.0
# 708           25360.0             3.8         14.690000           30550.0
# 709           22530.0             3.5         24.730000           51430.0
# 710            3600.0            18.7         14.710000           30590.0
# 711            8020.0             6.6         25.090000           52190.0
# 712            3900.0             7.5         15.170000           31560.0
# 713          108460.0             2.2          8.300000           17270.0
# 714          102550.0             2.1          8.540000           17770.0
# 715            5370.0             2.0         16.500000           34320.0
# 716           28340.0             2.5         23.059999           47970.0
# 717           59240.0             2.4         12.400000           25790.0
# 718           49060.0             2.6         18.420000           38320.0
# 719            2850.0            10.6         14.300000           29740.0
# 720           67210.0             3.6         16.770000           34880.0
# 721            3200.0             8.5         15.620000           32480.0
# 722            8970.0             5.8         17.290001           35960.0
# 723          586660.0             0.8         13.340000           27740.0
# 724          311070.0             1.0          9.050000           18830.0
# 725         2217590.0             1.1         10.320000           21460.0
# 726          162670.0             1.6         11.230000           23360.0
# 727          927740.0             1.1          8.730000           18160.0
# 728            6920.0            10.8         20.639999           42920.0
# 729           12360.0            10.6         18.580000           38640.0
# 730           10280.0            12.5         16.480000           34290.0
# 731          132290.0             4.1         12.550000           26090.0
# 732            3070.0             6.3         17.809999           37050.0
# 733           16960.0             5.3         17.030001           35420.0
#
#     mean_wage_RSE hourly_10th_percentile_wage hourly_25th_percentile_wage  \
# 0             0.2                        6.95                        8.93
# 1             0.2                       15.31                       21.86
# 2             0.3                       24.83                       38.88
# 3             0.2                       15.72                       21.98
# 4             2.2                        5.83                        6.34
# 5             0.7                       14.57                       19.01
# 6             0.4                        19.1                       26.33
# 7             0.3                       17.95                       24.72
# 8             0.8                       15.84                       21.35
# 9             0.4                       12.56                        17.4
# 10            0.3                       22.81                       30.84
# 11            0.5                       18.81                       25.23
# 12            0.3                       17.44                        22.8
# 13            0.3                       18.74                       24.38
# 14            0.4                       15.54                          21
# 15            0.4                        16.5                       21.78
# 16            1.3                       11.74                       15.68
# 17            0.7                       18.33                       23.42
# 18            1.4                        9.58                       12.12
# 19              2                           *                           *
# 20            0.8                       17.26                       22.62
# 21            0.3                       27.81                       34.85
# 22            5.7                       10.46                       13.42
# 23            2.5                          12                       16.13
# 24            1.4                        14.9                       19.91
# 25            0.9                        9.81                       12.55
# 26            0.4                       18.01                       23.03
# 27            1.3                       21.94                       28.85
# 28            0.1                       16.88                       19.46
# 29            0.9                        8.39                       12.24
# ..            ...                         ...                         ...
# 704           2.1                       12.54                       15.17
# 705           1.3                       13.32                       17.13
# 706           2.6                       15.19                        18.1
# 707             4                       17.87                       20.48
# 708           1.3                        7.92                       10.29
# 709           1.3                       12.28                       17.48
# 710           6.3                        7.51                        8.77
# 711           1.7                       12.95                       18.31
# 712           2.2                         7.6                        9.87
# 713           0.6                         6.1                        6.89
# 714           0.7                        6.19                        6.98
# 715           1.7                        9.52                        11.6
# 716           1.3                       10.54                       16.68
# 717           0.8                        8.04                         9.6
# 718           1.2                       11.07                        13.5
# 719           2.9                        8.17                       10.25
# 720           1.8                       10.01                       12.26
# 721           1.9                       10.25                        12.4
# 722           2.3                        9.45                       11.47
# 723           0.4                        8.82                       10.28
# 724           0.4                        6.12                        6.94
# 725           0.3                        6.64                        7.69
# 726           0.5                        7.28                        8.53
# 727           0.3                        6.12                        6.89
# 728           2.8                       12.77                       16.12
# 729           2.6                        9.47                       12.66
# 730           2.3                        9.33                       12.18
# 731           2.1                        6.28                        8.18
# 732           1.2                       13.09                       15.17
# 733           2.1                        9.52                       11.83
#
#      hourly_median_wage hourly 75_percentile_wage hourly_90th_percentile_wage  \
# 0             13.310000                     20.84                        31.2
# 1             32.270000                     46.79                       69.53
# 2             60.700001                       NaN                         NaN
# 3             32.799999                     50.47                         NaN
# 4              7.320000                     18.53                       33.36
# 5             27.469999                     41.21                       60.13
# 6             37.619999                     52.49                         NaN
# 7             36.080002                     51.82                         NaN
# 8             29.150000                     41.15                       56.63
# 9             25.240000                     35.86                       48.02
# 10            40.980000                     52.86                       67.52
# 11            35.259998                     48.39                       68.39
# 12            31.110001                     42.36                       54.95
# 13            32.369999                     42.73                       55.17
# 14            28.790001                      39.4                       51.99
# 15            28.680000                      37.8                       48.51
# 16            21.030001                     28.52                       38.99
# 17            30.530001                     40.43                       54.23
# 18            16.030001                     22.48                       32.53
# 19                  NaN                         *                           *
# 20            31.080000                     42.36                       55.87
# 21            43.709999                     54.83                       67.97
# 22            17.209999                     22.65                       32.45
# 23            20.850000                     27.95                       40.42
# 24            26.120001                     34.92                       47.39
# 25            16.330000                     21.48                       28.57
# 26            29.500000                     38.53                       52.44
# 27            39.540001                      53.4                       69.51
# 28            23.340000                     26.95                       31.95
# 29            17.730000                     26.92                       41.66
# ..                  ...                       ...                         ...
# 704           18.070000                        21                       25.12
# 705           20.930000                     26.32                       33.12
# 706           21.389999                     28.61                       37.88
# 707           23.540001                      25.8                       27.16
# 708           13.640000                     18.74                       22.16
# 709           23.969999                      30.2                       37.04
# 710           12.710000                     19.83                       24.84
# 711           24.610001                     31.51                       37.37
# 712           16.980000                     19.52                       21.17
# 713            7.840000                      9.12                       11.17
# 714            7.970000                      9.36                       11.68
# 715           15.220000                     20.61                       26.06
# 716           23.299999                     27.91                       36.12
# 717           11.660000                     14.23                       18.39
# 718           17.469999                     22.07                       28.02
# 719           13.330000                      17.1                       22.71
# 720           15.580000                     20.56                       26.15
# 721           15.350000                     18.47                       21.72
# 722           15.090000                     21.02                       30.85
# 723           12.540000                     15.59                       19.52
# 724            8.200000                     10.31                       13.32
# 725            9.480000                     11.94                       15.49
# 726           10.500000                     13.19                       16.63
# 727            8.030000                     10.03                       12.65
# 728           20.440001                     25.01                       28.73
# 729           17.530001                     24.99                       28.17
# 730           16.240000                     20.94                       23.74
# 731           11.600000                     15.92                       21.07
# 732           18.440001                     20.71                       22.17
# 733           15.630000                     21.81                       27.38
#
#     annual_10th_percentile_wage annual_25th_percentile_wage  \
# 0                         14450                       18580
# 1                         31850                       45470
# 2                         51650                       80860
# 3                         32700                       45720
# 4                         12130                       13180
# 5                         30310                       39550
# 6                         39730                       54760
# 7                         37340                       51430
# 8                         32960                       44410
# 9                         26120                       36190
# 10                        47440                       64150
# 11                        39120                       52490
# 12                        36280                       47420
# 13                        38980                       50710
# 14                        32330                       43670
# 15                        34330                       45290
# 16                        24410                       32620
# 17                        38130                       48720
# 18                        19930                       25200
# 19                        48700                       58820
# 20                        35910                       47050
# 21                        57840                       72480
# 22                        21760                       27910
# 23                        24950                       33540
# 24                        30980                       41410
# 25                        20400                       26110
# 26                        37460                       47910
# 27                        45640                       60000
# 28                        35110                       40470
# 29                        17450                       25470
# ..                          ...                         ...
# 704                       26090                       31550
# 705                       27710                       35620
# 706                       31600                       37650
# 707                       37160                       42600
# 708                       16470                       21400
# 709                       25540                       36360
# 710                       15620                       18240
# 711                       26930                       38080
# 712                       15800                       20530
# 713                       12690                       14320
# 714                       12880                       14520
# 715                       19810                       24140
# 716                       21930                       34690
# 717                       16730                       19970
# 718                       23030                       28080
# 719                       16990                       21310
# 720                       20820                       25500
# 721                       21320                       25790
# 722                       19650                       23850
# 723                       18360                       21380
# 724                       12740                       14430
# 725                       13820                       15990
# 726                       15130                       17740
# 727                       12720                       14340
# 728                       26550                       33530
# 729                       19700                       26330
# 730                       19420                       25330
# 731                       13070                       17010
# 732                       27230                       31550
# 733                       19810                       24600
#
#     annual_median_percentile_wage annual_75th_percentile_wage  \
# 0                           27690                       43340
# 1                           67120                       97320
# 2                          126260                         NaN
# 3                           68210                      104970
# 4                           15220                       38540
# 5                           57130                       85710
# 6                           78250                      109190
# 7                           75040                      107790
# 8                           60640                       85590
# 9                           52500                       74590
# 10                          85240                      109950
# 11                          73340                      100660
# 12                          64710                       88100
# 13                          67320                       88880
# 14                          59890                       81950
# 15                          59660                       78620
# 16                          43740                       59330
# 17                          63500                       84080
# 18                          33340                       46760
# 19                          71490                       87540
# 20                          64640                       88110
# 21                          90930                      114050
# 22                          35790                       47120
# 23                          43380                       58140
# 24                          54330                       72630
# 25                          33970                       44670
# 26                          61370                       80150
# 27                          82250                      111070
# 28                          48540                       56050
# 29                          36880                       56000
# ..                            ...                         ...
# 704                         37590                       43680
# 705                         43520                       54750
# 706                         44490                       59510
# 707                         48970                       53670
# 708                         28370                       38990
# 709                         49850                       62810
# 710                         26440                       41250
# 711                         51190                       65540
# 712                         35310                       40610
# 713                         16320                       18970
# 714                         16570                       19470
# 715                         31650                       42860
# 716                         48450                       58050
# 717                         24250                       29590
# 718                         36330                       45910
# 719                         27730                       35570
# 720                         32410                       42760
# 721                         31930                       38420
# 722                         31400                       43730
# 723                         26070                       32430
# 724                         17060                       21450
# 725                         19710                       24830
# 726                         21840                       27440
# 727                         16700                       20860
# 728                         42510                       52030
# 729                         36470                       51980
# 730                         33770                       43560
# 731                         24130                       33120
# 732                         38360                       43070
# 733                         32500                       45360
#
#     annual_90th_percentile_wage  Year
# 0                         64900  2002
# 1                        144620  2002
# 2                           NaN  2002
# 3                           NaN  2002
# 4                         69380  2002
# 5                        125070  2002
# 6                           NaN  2002
# 7                           NaN  2002
# 8                        117780  2002
# 9                         99870  2002
# 10                       140440  2002
# 11                       142260  2002
# 12                       114300  2002
# 13                       114750  2002
# 14                       108140  2002
# 15                       100900  2002
# 16                        81100  2002
# 17                       112810  2002
# 18                        67650  2002
# 19                       104870  2002
# 20                       116210  2002
# 21                       141380  2002
# 22                        67490  2002
# 23                        84060  2002
# 24                        98570  2002
# 25                        59420  2002
# 26                       109080  2002
# 27                       144590  2002
# 28                        66450  2002
# 29                        86650  2002
# ..                          ...   ...
# 704                       52260  2002
# 705                       68900  2002
# 706                       78790  2002
# 707                       56500  2002
# 708                       46090  2002
# 709                       77050  2002
# 710                       51670  2002
# 711                       77740  2002
# 712                       44030  2002
# 713                       23230  2002
# 714                       24300  2002
# 715                       54200  2002
# 716                       75120  2002
# 717                       38250  2002
# 718                       58280  2002
# 719                       47240  2002
# 720                       54390  2002
# 721                       45180  2002
# 722                       64160  2002
# 723                       40590  2002
# 724                       27710  2002
# 725                       32220  2002
# 726                       34600  2002
# 727                       26310  2002
# 728                       59750  2002
# 729                       58590  2002
# 730                       49370  2002
# 731                       43820  2002
# 732                       46120  2002
# 733                       56940  2002
#
# [734 rows x 19 columns]

# %%
all_list= (df_2002, df_2003, df_2004, df_2005, df_2006, df_2007, df_2008, df_2009, df_2010, df_2011, df_2012, df_2013, df_2014, df_2015, df_2016)
df_all_labor= pd.concat(all_list)

# %% [markdown]
# Note for reference from Data source:
# occ_group: Shows the SOC occupation level: "total"=total of all occupations; "major"=SOC major group; "minor"=SOC minor group; "broad"=SOC broad occupation; "detailed"=SOC detailed occupation

# %%
df_all_labor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15012 entries, 0 to 1393
# Data columns (total 19 columns):
# OCC_Code                         15012 non-null object
# Occupation_title                 15012 non-null object
# OCC_group                        15012 non-null object
# total_employment                 15009 non-null float32
# Employment_RSE                   15009 non-null object
# mean_hourly_wage                 14033 non-null float32
# mean_annual_wage                 14940 non-null float32
# mean_wage_RSE                    15012 non-null object
# hourly_10th_percentile_wage      15012 non-null object
# hourly_25th_percentile_wage      14978 non-null object
# hourly_median_wage               13921 non-null float32
# hourly 75_percentile_wage        14786 non-null object
# hourly_90th_percentile_wage      14391 non-null object
# annual_10th_percentile_wage      15012 non-null object
# annual_25th_percentile_wage      14978 non-null object
# annual_median_percentile_wage    14900 non-null object
# annual_75th_percentile_wage      14782 non-null object
# annual_90th_percentile_wage      14334 non-null object
# Year                             15012 non-null object
# dtypes: float32(4), object(15)
# memory usage: 2.1+ MB

# %%
# check for null values
df_all_labor.isnull().sum()
# Out:
# OCC_Code                            0
# Occupation_title                    0
# OCC_group                           0
# total_employment                    3
# Employment_RSE                      3
# mean_hourly_wage                  979
# mean_annual_wage                   72
# mean_wage_RSE                       0
# hourly_10th_percentile_wage         0
# hourly_25th_percentile_wage        34
# hourly_median_wage               1091
# hourly 75_percentile_wage         226
# hourly_90th_percentile_wage       621
# annual_10th_percentile_wage         0
# annual_25th_percentile_wage        34
# annual_median_percentile_wage     112
# annual_75th_percentile_wage       230
# annual_90th_percentile_wage       678
# Year                                0
# dtype: int64

# %%
df_all_labor.head()
# Out:
#   OCC_Code                 Occupation_title OCC_group  total_employment  \
# 0  00-0000                  All Occupations     major       127523760.0
# 1  11-0000           Management Occupations     major         7092460.0
# 2  11-1011                 Chief Executives                    452400.0
# 3  11-1021  General and Operations Managers                   1998350.0
# 4  11-1031                      Legislators                     64650.0
#
#   Employment_RSE  mean_hourly_wage  mean_annual_wage mean_wage_RSE  \
# 0            0.1         17.100000           35560.0           0.2
# 1            0.3         37.919998           78870.0           0.2
# 2            0.7         64.889999          134960.0           0.3
# 3            0.4         40.189999           83590.0           0.2
# 4            3.5         14.620000           30420.0           2.2
#
#   hourly_10th_percentile_wage hourly_25th_percentile_wage  hourly_median_wage  \
# 0                        6.95                        8.93           13.310000
# 1                       15.31                       21.86           32.270000
# 2                       24.83                       38.88           60.700001
# 3                       15.72                       21.98           32.799999
# 4                        5.83                        6.34            7.320000
#
#   hourly 75_percentile_wage hourly_90th_percentile_wage  \
# 0                     20.84                        31.2
# 1                     46.79                       69.53
# 2                       NaN                         NaN
# 3                     50.47                         NaN
# 4                     18.53                       33.36
#
#   annual_10th_percentile_wage annual_25th_percentile_wage  \
# 0                       14450                       18580
# 1                       31850                       45470
# 2                       51650                       80860
# 3                       32700                       45720
# 4                       12130                       13180
#
#   annual_median_percentile_wage annual_75th_percentile_wage  \
# 0                         27690                       43340
# 1                         67120                       97320
# 2                        126260                         NaN
# 3                         68210                      104970
# 4                         15220                       38540
#
#   annual_90th_percentile_wage  Year
# 0                       64900  2002
# 1                      144620  2002
# 2                         NaN  2002
# 3                         NaN  2002
# 4                       69380  2002

# %%
df_all_labor.tail()
# Out:
#      OCC_Code                       Occupation_title OCC_group  \
# 1389  53-7111             Mine Shuttle Car Operators  detailed
# 1390  53-7120      Tank Car, Truck, and Ship Loaders     broad
# 1391  53-7121      Tank Car, Truck, and Ship Loaders  detailed
# 1392  53-7190  Miscellaneous Material Moving Workers     broad
# 1393  53-7199     Material Moving Workers, All Other  detailed
#
#       total_employment Employment_RSE  mean_hourly_wage  mean_annual_wage  \
# 1389            1590.0              7         27.100000           56370.0
# 1390           10920.0           13.1         19.040001           39590.0
# 1391           10920.0           13.1         19.040001           39590.0
# 1392           23880.0            3.7         16.610001           34540.0
# 1393           23880.0            3.7         16.610001           34540.0
#
#      mean_wage_RSE hourly_10th_percentile_wage hourly_25th_percentile_wage  \
# 1389           1.3                       21.21                       23.98
# 1390           2.5                       10.82                       13.25
# 1391           2.5                       10.82                       13.25
# 1392             2                       10.00                       10.85
# 1393             2                       10.00                       10.85
#
#       hourly_median_wage hourly 75_percentile_wage  \
# 1389           27.139999                     29.91
# 1390           17.200001                     22.78
# 1391           17.200001                     22.78
# 1392           13.640000                     20.65
# 1393           13.640000                     20.65
#
#      hourly_90th_percentile_wage annual_10th_percentile_wage  \
# 1389                       32.73                       44120
# 1390                       31.82                       22510
# 1391                       31.82                       22510
# 1392                       28.29                       20810
# 1393                       28.29                       20810
#
#      annual_25th_percentile_wage annual_median_percentile_wage  \
# 1389                       49880                         56450
# 1390                       27570                         35770
# 1391                       27570                         35770
# 1392                       22570                         28370
# 1393                       22570                         28370
#
#      annual_75th_percentile_wage annual_90th_percentile_wage  Year
# 1389                       62200                       68080  2016
# 1390                       47380                       66190  2016
# 1391                       47380                       66190  2016
# 1392                       42950                       58840  2016
# 1393                       42950                       58840  2016

# %%
df_2016_major= df_2016.loc[df_2016['OCC_group']== 'major' ]

# %%
import matplotlib.cm as cm
colors=cm.rainbow(np.random.rand(33))

E= df_2016_major.total_employment
A= df_2016_major.mean_annual_wage
T= df_2016_major.Occupation_title
H= df_2016_major.mean_hourly_wage


plot=plt.scatter(x=df_2016_major.total_employment, y = df_2016_major.mean_hourly_wage, 
                  alpha=0.9, c= colors, edgecolors= 'black')
plt.title('2016: Total Employment by Hourly Wage for different job types', fontsize = 35)
plt.suptitle('National Average from Labor Board', fontsize= 15)
plt.xlabel('Total Employment Numbers: 1 million', fontsize= 15)
plt.ylabel('Mean Hourly Wage')
plt.show()

# %%
# isolating the total list by only the major job types
df_all_major= df_all_labor.loc[df_all_labor['OCC_group']== 'major' ]
df_all_broad= df_all_labor.loc[df_all_labor['OCC_group']== 'broad' ]

# %%
import matplotlib.cm as cm
colors=cm.rainbow(np.random.rand(33))

E= df_all_major.total_employment
A= df_all_major.mean_annual_wage
T= df_all_major.Occupation_title
H= df_all_major.mean_hourly_wage
Z= df_all_major.Year

plot=plt.scatter(x= E, y = H, 
                  alpha=0.9, c= colors, edgecolors= 'black')
plt.title('2016: Total Employment by Hourly Wage for different job types', fontsize= 35)
plt.suptitle('National Average from Labor Board', fontsize= 25)
plt.xlabel('Total Employment Numbers: values in millions', fontsize= 15)
plt.ylabel('Mean Hourly Wage', fontsize = 15)
plt.xlim(xmin=0, xmax= 20000000)
plt.show()

# %%
sns.lmplot( x='total_employment', y='mean_hourly_wage', data=df_all_major, fit_reg=False, hue='Year')
plt.xlim(xmin=0, xmax= 20000000)
plt.title('Total Employment by Hourly Wage for different job types', fontsize= 25)
plt.suptitle('National Average from Labor Board', fontsize= 15)
plt.xlabel('Total Employment Numbers: values in millions', fontsize= 10)
plt.ylabel('Mean Hourly Wage per Job', fontsize= 10)
plt.show()

# %%
sns.lmplot( x='total_employment', y='mean_hourly_wage', data=df_all_major, fit_reg=False, hue='Occupation_title')
plt.xlim(xmin=0, xmax= 20000000)
plt.title('Total Employment by Hourly Wage for different job types', fontsize= 25)
plt.suptitle('National Average from Labor Board: 2002-2016', fontsize= 15)
plt.xlabel('Total Employment Numbers: values in millions', fontsize= 10)
plt.ylabel('Mean Hourly Wage per Job', fontsize= 10)
plt.show()

# %% [markdown]
# # Thoughts
# Looking at employment numbers (amount of people employed in a career/job type) versus pay for all the years there is still a general correlation. OVerall, the most common jobs are in the lower paying quartiles, with no exceptions below 0.8 million employed in the US in the given year. Although surprinsgly the most highly paied jobs are not the rarest, and there are a few rare jobs that are very low pay scales.
#
# I am going to look at the same thing below, by broad job description

# %%
colors=cm.rainbow(np.random.rand(33))

E= df_all_broad.total_employment
A= df_all_broad.mean_annual_wage
T= df_all_broad.Occupation_title
H= df_all_broad.mean_hourly_wage
Z= df_all_broad.Year

plot=plt.scatter(x= E, y = H, s=100,
                  alpha=0.5, c= colors, edgecolors= 'black')
plt.title('Total Employment by Hourly Wage for Broad Job Types', fontsize= 35)
plt.suptitle('National Average from Labor Board:2002-2016', fontsize= 25)
plt.xlabel('Total Employment Numbers', fontsize= 15)
plt.ylabel('Mean Hourly Wage', fontsize = 15)
plt.xlim(xmin=0, xmax= 2000000)
plt.show()

# %%
colors=cm.rainbow(np.random.rand(33))

E= df_all_broad.total_employment
A= df_all_broad.mean_annual_wage
T= df_all_broad.Occupation_title
H= df_all_broad.mean_hourly_wage
Z= df_all_broad.Year

plot=plt.scatter(x= E, y = A, s=100,
                  alpha=0.5, c= colors, edgecolors= 'black')
plt.title('Total Employment by Annual Wage for Broad Job Types', fontsize= 35)
plt.suptitle('National Average from Labor Board:2002-2016', fontsize= 25)
plt.xlabel('Total Employment Numbers', fontsize= 15)
plt.ylabel('Mean Hourly Wage', fontsize = 15)
plt.xlim(xmin=0, xmax= 2000000)
plt.show()

# %%
sns.lmplot( x='total_employment', y='mean_hourly_wage', data=df_all_broad, fit_reg=False, hue='Year')
plt.xlim(xmin=0, xmax= 20000000)
plt.title('Total Employment by Hourly Wage for different job types: Broad Descriptions', fontsize= 20)
plt.suptitle('National Average from Labor Board', fontsize= 15)
plt.xlabel('Total Employment Numbers', fontsize= 10)
plt.ylabel('Mean Hourly Wage per Job', fontsize= 10)
plt.xlim(xmin=0, xmax= 5000000)
plt.show()

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 20
fig_size[1] = 10

_= plt.figure(figsize=(20,15))

_= sns.factorplot( y='mean_annual_wage', x='Year',data= df_all_major, kind='strip')
_= plt.xticks( rotation= 45,  size= 5)
_=plt.xlabel('Year')
_=plt.ylabel('Mean Annual Wage')
_=plt.title('Mean Annual Wages for Various Jobs from 2002-2016')

_= plt.show()

# %% [markdown]
# # thoughts, Early Analysis
# There appear to be three seperate groupings of types of jobs, with big gaps in mean wage between them. From 2006-2009 (through the recent financial crisis) there also appears to be a bump in wages, most prominently in the top grouping. -- also important to note- the highest line here is the "All Occupations group" so it can be read as a total average

# %% [markdown]
# # Incorperate GDP data
# isolate GDP from the world bank data by year, switch column and row, and join to existing df along year listing as GDP column

# %%
df_World_Bank.head(3)
# Out:
#               Country Code                                     Indicator Name  \
# Country Name
# United States          USA  Share of tariff lines with specific rates, man...
# United States          USA  Tariff rate, most favored nation, simple mean,...
# United States          USA  Tariff rate, applied, simple mean, manufacture...
#
#                      Indicator Code 1960 1961 1962 1963 1964 1965 1966  \
# Country Name
# United States     TM.TAX.MANF.SR.ZS
# United States  TM.TAX.MANF.SM.FN.ZS
# United States  TM.TAX.MANF.SM.AR.ZS
#
#                   ...          2009      2010      2011      2012      2013  \
# Country Name      ...
# United States     ...      2.962173  2.835324  2.872772  2.866434  2.784078
# United States     ...          3.65      3.65      3.65      3.65      3.65
# United States     ...          2.95      2.93      3.02      3.02      2.88
#
#                    2014      2015      2016 2017 Unnamed: 62
# Country Name
# United States  2.909892  2.886122  2.886176
# United States      3.65      3.64      3.64
# United States      2.95      2.87      2.87
#
# [3 rows x 62 columns]

# %%
df_WB_GDP_unedited= df_World_Bank.loc[df_World_Bank['Indicator Name'] == 'GDP per capita (current US$)']
df_WB_GDP_growth_unedited= df_World_Bank.loc[df_World_Bank['Indicator Name'] == 'GDP growth (annual %)']
df_WB_GDP_worker_unedited= df_World_Bank.loc[df_World_Bank['Indicator Name'] == 'GDP per person employed (constant 2011 PPP $)']


df_WB_male_employmentper_unedited= df_World_Bank.loc[df_World_Bank['Indicator Name'] == 'Employment in industry, male (% of male employment) (modeled ILO estimate)']
df_WB_female_employmentper_unedited= df_World_Bank.loc[df_World_Bank['Indicator Name'] == 'Employment in industry, female (% of female employment) (modeled ILO estimate)']

# %%
# clean and transpose the DF so years are rows then concat into one DF
def clean_WB(df):
    df.columns= df.columns.get_level_values(0)
    df1= df.reset_index()
    df2= df1.drop(['Indicator Code', 'Country Code', 'Country Name'], axis= 1)
    df3= df2.transpose()
    return df3

# %%
df_WB1= clean_WB(df_WB_GDP_unedited)
df_WB2= clean_WB(df_WB_GDP_growth_unedited)
df_WB3= clean_WB(df_WB_GDP_worker_unedited)

df_WB4= clean_WB(df_WB_male_employmentper_unedited)
df_WB5= clean_WB(df_WB_female_employmentper_unedited)

# %%
all_df= [df_WB1, df_WB2, df_WB3, df_WB4, df_WB5]

df_WB_GDP_plus= pd.concat(all_df, axis=1, join='inner')
df_WB_GDP_plus= df_WB_GDP_plus.drop(df_WB_GDP_plus.index[0])
df_WB_GDP_plus= df_WB_GDP_plus.reset_index()
df_WB_GDP_plus.columns= ('Year', 'GDP per capita (current US$)','GDP growth (annual %)', 'GDP per person employed (constant 2011 PPP$)', 
                        'Employment in all industry, male (%)', 'Employment in all industry, female (%)')
# only interestd in data from 2002 on
df_WB_GDP_recent= df_WB_GDP_plus.drop(df_WB_GDP_plus.index[0:42])
df_WB_GDP_recent
# Out:
#            Year GDP per capita (current US$) GDP growth (annual %)  \
# 42         2002             38166.0378407812      1.78612768745552
# 43         2003             39677.1983481058      2.80677595648093
# 44         2004             41921.8097617892      3.78574284969444
# 45         2005             44307.9205848603      3.34521606334877
# 46         2006             46437.0671173065        2.666625826122
# 47         2007             48061.5376613353      1.77857023965289
# 48         2008             48401.4273403899    -0.291621458693953
# 49         2009             47001.5553496818     -2.77552957416808
# 50         2010             48373.8788155779      2.53192061616315
# 51         2011             49790.6654782305      1.60145467247139
# 52         2012             51450.1222950581      2.22403085385714
# 53         2013             52787.0269489935      1.67733152992453
# 54         2014             54598.5506887519      2.56919359418927
# 55         2015             56469.0089691129      2.86158702527237
# 56         2016             57638.1590879883      1.48527919319147
# 57         2017
# 58  Unnamed: 62
#
#    GDP per person employed (constant 2011 PPP$)  \
# 42                                        95440
# 43                                        97912
# 44                                       100435
# 45                                       102124
# 46                                       103062
# 47                                       104015
# 48                                       103863
# 49                                       104800
# 50                                       107956
# 51                                       108733
# 52                                       109261
# 53                                       109874
# 54                                       110579
# 55                                       111561
# 56                                       112089
# 57                                       113922
# 58
#
#    Employment in all industry, male (%) Employment in all industry, female (%)
# 42                     30.1000003814697                                   10.5
# 43                     29.7000007629395                       9.80000019073486
# 44                     29.2999992370605                                    9.5
# 45                     29.3999996185303                       9.30000019073486
# 46                     29.7000007629395                       9.10000038146973
# 47                                 29.5                       9.19999980926514
# 48                                 28.5                       8.80000019073486
# 49                     27.2999992370605                                      8
# 50                     26.6000003814697                       7.59999990463257
# 51                                 26.5                       7.59999990463257
# 52                                 26.5                                    7.5
# 53                     26.2999992370605                       7.40000009536743
# 54                     26.2000007629395                       7.30000019073486
# 55                     26.2000007629395                       7.19999980926514
# 56                     25.8999996185303                                      7
# 57                     25.7999992370605                                      7
# 58

# %%
df_WB_GDP_recent['GDP per capita (current US$)']= pd.to_numeric(df_WB_GDP_recent['GDP per capita (current US$)'], errors='coerce', downcast='float')
df_WB_GDP_recent['GDP growth (annual %)']= pd.to_numeric(df_WB_GDP_recent['GDP growth (annual %)'], errors='coerce')
df_WB_GDP_recent['GDP per person employed (constant 2011 PPP$)']= pd.to_numeric(df_WB_GDP_recent['GDP per person employed (constant 2011 PPP$)'], errors='coerce')
df_WB_GDP_recent['Employment in all industry, male (%)']= pd.to_numeric(df_WB_GDP_recent['Employment in all industry, male (%)'], errors='coerce')
df_WB_GDP_recent['Employment in all industry, female (%)']= pd.to_numeric(df_WB_GDP_recent['Employment in all industry, female (%)'], errors='coerce')
df_WB_GDP_recent.head(3)
# Out:
#     Year  GDP per capita (current US$)  GDP growth (annual %)  \
# 42  2002                  38166.039062               1.786128
# 43  2003                  39677.199219               2.806776
# 44  2004                  41921.808594               3.785743
#
#     GDP per person employed (constant 2011 PPP$)  \
# 42                                       95440.0
# 43                                       97912.0
# 44                                      100435.0
#
#     Employment in all industry, male (%)  \
# 42                             30.100000
# 43                             29.700001
# 44                             29.299999
#
#     Employment in all industry, female (%)
# 42                                    10.5
# 43                                     9.8
# 44                                     9.5

# %%
df_WB_GDP_recent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17 entries, 42 to 58
# Data columns (total 6 columns):
# Year                                            17 non-null object
# GDP per capita (current US$)                    15 non-null float32
# GDP growth (annual %)                           15 non-null float64
# GDP per person employed (constant 2011 PPP$)    16 non-null float64
# Employment in all industry, male (%)            16 non-null float64
# Employment in all industry, female (%)          16 non-null float64
# dtypes: float32(1), float64(4), object(1)
# memory usage: 884.0+ bytes

# %%
sns.factorplot(y='Employment in all industry, male (%)' ,x='Year' ,data=df_WB_GDP_recent, color= 'blue')
sns.factorplot(y='Employment in all industry, female (%)' ,x='Year' ,data=df_WB_GDP_recent, color='magenta')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Put GDP info w/ Salary info by job type
# Do initial exploratory Graph and first thoughts/findings

# %%
df_GDP_salary= pd.merge(df_WB_GDP_recent, df_all_labor, left_on= 'Year', right_on='Year')

# %%
df_GDP_salary.head()
# Out:
#    Year  GDP per capita (current US$)  GDP growth (annual %)  \
# 0  2002                  38166.039062               1.786128
# 1  2002                  38166.039062               1.786128
# 2  2002                  38166.039062               1.786128
# 3  2002                  38166.039062               1.786128
# 4  2002                  38166.039062               1.786128
#
#    GDP per person employed (constant 2011 PPP$)  \
# 0                                       95440.0
# 1                                       95440.0
# 2                                       95440.0
# 3                                       95440.0
# 4                                       95440.0
#
#    Employment in all industry, male (%)  \
# 0                                  30.1
# 1                                  30.1
# 2                                  30.1
# 3                                  30.1
# 4                                  30.1
#
#    Employment in all industry, female (%) OCC_Code  \
# 0                                    10.5  00-0000
# 1                                    10.5  11-0000
# 2                                    10.5  11-1011
# 3                                    10.5  11-1021
# 4                                    10.5  11-1031
#
#                   Occupation_title OCC_group  total_employment  \
# 0                  All Occupations     major       127523760.0
# 1           Management Occupations     major         7092460.0
# 2                 Chief Executives                    452400.0
# 3  General and Operations Managers                   1998350.0
# 4                      Legislators                     64650.0
#
#               ...             hourly_10th_percentile_wage  \
# 0             ...                                    6.95
# 1             ...                                   15.31
# 2             ...                                   24.83
# 3             ...                                   15.72
# 4             ...                                    5.83
#
#    hourly_25th_percentile_wage  hourly_median_wage hourly 75_percentile_wage  \
# 0                         8.93           13.310000                     20.84
# 1                        21.86           32.270000                     46.79
# 2                        38.88           60.700001                       NaN
# 3                        21.98           32.799999                     50.47
# 4                         6.34            7.320000                     18.53
#
#   hourly_90th_percentile_wage annual_10th_percentile_wage  \
# 0                        31.2                       14450
# 1                       69.53                       31850
# 2                         NaN                       51650
# 3                         NaN                       32700
# 4                       33.36                       12130
#
#    annual_25th_percentile_wage annual_median_percentile_wage  \
# 0                        18580                         27690
# 1                        45470                         67120
# 2                        80860                        126260
# 3                        45720                         68210
# 4                        13180                         15220
#
#   annual_75th_percentile_wage annual_90th_percentile_wage
# 0                       43340                       64900
# 1                       97320                      144620
# 2                         NaN                         NaN
# 3                      104970                         NaN
# 4                       38540                       69380
#
# [5 rows x 24 columns]

# %%
df_GDP_salary.tail()
# Out:
#        Year  GDP per capita (current US$)  GDP growth (annual %)  \
# 15007  2016                  57638.160156               1.485279
# 15008  2016                  57638.160156               1.485279
# 15009  2016                  57638.160156               1.485279
# 15010  2016                  57638.160156               1.485279
# 15011  2016                  57638.160156               1.485279
#
#        GDP per person employed (constant 2011 PPP$)  \
# 15007                                      112089.0
# 15008                                      112089.0
# 15009                                      112089.0
# 15010                                      112089.0
# 15011                                      112089.0
#
#        Employment in all industry, male (%)  \
# 15007                                  25.9
# 15008                                  25.9
# 15009                                  25.9
# 15010                                  25.9
# 15011                                  25.9
#
#        Employment in all industry, female (%) OCC_Code  \
# 15007                                     7.0  53-7111
# 15008                                     7.0  53-7120
# 15009                                     7.0  53-7121
# 15010                                     7.0  53-7190
# 15011                                     7.0  53-7199
#
#                             Occupation_title OCC_group  total_employment  \
# 15007             Mine Shuttle Car Operators  detailed            1590.0
# 15008      Tank Car, Truck, and Ship Loaders     broad           10920.0
# 15009      Tank Car, Truck, and Ship Loaders  detailed           10920.0
# 15010  Miscellaneous Material Moving Workers     broad           23880.0
# 15011     Material Moving Workers, All Other  detailed           23880.0
#
#                   ...             hourly_10th_percentile_wage  \
# 15007             ...                                   21.21
# 15008             ...                                   10.82
# 15009             ...                                   10.82
# 15010             ...                                   10.00
# 15011             ...                                   10.00
#
#        hourly_25th_percentile_wage  hourly_median_wage  \
# 15007                        23.98           27.139999
# 15008                        13.25           17.200001
# 15009                        13.25           17.200001
# 15010                        10.85           13.640000
# 15011                        10.85           13.640000
#
#       hourly 75_percentile_wage hourly_90th_percentile_wage  \
# 15007                     29.91                       32.73
# 15008                     22.78                       31.82
# 15009                     22.78                       31.82
# 15010                     20.65                       28.29
# 15011                     20.65                       28.29
#
#       annual_10th_percentile_wage  annual_25th_percentile_wage  \
# 15007                       44120                        49880
# 15008                       22510                        27570
# 15009                       22510                        27570
# 15010                       20810                        22570
# 15011                       20810                        22570
#
#       annual_median_percentile_wage annual_75th_percentile_wage  \
# 15007                         56450                       62200
# 15008                         35770                       47380
# 15009                         35770                       47380
# 15010                         28370                       42950
# 15011                         28370                       42950
#
#       annual_90th_percentile_wage
# 15007                       68080
# 15008                       66190
# 15009                       66190
# 15010                       58840
# 15011                       58840
#
# [5 rows x 24 columns]

# %%
sns.violinplot(x= 'Year', y='hourly_median_wage', data= df_GDP_salary)
plt.title('Mean Hourly Wage By Year: 2002-2016')
plt.xlabel('Year', fontsize= 12)
plt.ylabel('Mean Hourly Wage', fontsize= 12)
plt.show()

# %%
sns.violinplot(x= 'Year', y='mean_annual_wage', data= df_GDP_salary)
plt.title('Mean Annual Wage By Year: 2002-2016')
plt.xlabel('Year', fontsize= 12)
plt.ylabel('Mean Hourly Wage', fontsize= 12)
plt.show()

# %%
sns.factorplot(x='mean_annual_wage', y='mean_hourly_wage', data= df_GDP_salary)
plt.show()

# %%
sns.factorplot(x='Year', y='mean_hourly_wage', 
               data= df_GDP_salary, kind= 'strip', hue='GDP per person employed (constant 2011 PPP$)', 
               jitter=True, size= 10, aspect= 4)
plt.title('Mean Hourly Wage by GDP per person')
plt.show()
